# %% [markdown]
# # FRI (most of the csv file have been filled manualy)

# %%
import os
import csv
import numpy as np
headers=['Name','Path','Identity','Gender_code','Gender','Age','Race','date of birth','Emotion_code','Neutral','Anger','Scream','Contempt',
         'Disgust','Fear','Happy','Sadness','Surprise','Sun glasses','Scarf','Eyeglasses','Beard',
         'Hat','Angle']

directory = "root_dir\datasets\original\\fri\img"
c=0
labels_fri=[]
for img_name in os.listdir(directory):

    c+=1
    nb_img = len(os.listdir(directory))
    progression = np.round(100*c/nb_img,2)
    print(f"\n Progession: {progression}% \n") 

    if img_name.lower().endswith(('.png', '.jpg', '.jpeg')):
        img_path = os.path.join(directory, img_name)
        
        label = {
        'Name':img_name,'Path':img_path,'Identity': img_name,'Gender_code':'','Gender': '', 'Age': '', 'Race': '', 'date of birth': '',
        'Emotion_code':'','Neutral': '', 'Anger': '', 'Scream': '', 'Contempt': '', 'Disgust': '',
        'Fear': '', 'Happy': '', 'Sadness': '', 'Surprise': '', 'Sun glasses': '',
        'Scarf': '', 'Eyeglasses': '', 'Beard': '', 'Hat': '', 'Angle': 0
    }
    labels_fri.append(label)


with open("root_dir\datasets\labels\\fri_labels.csv","w",newline = '') as csv_file:
    csv_writer = csv.DictWriter(csv_file,fieldnames=headers)
    csv_writer.writeheader()
    csv_writer.writerows(labels_fri)


with open("root_dir\datasets\labels\\fri_labels.csv","r",newline = '') as csv_file:
    csv_reader = csv.reader(csv_file)
    c=0
    for line in csv_reader:
        print(line)
# Out:
#  Progession: 3.7%
#
#
#  Progession: 7.41%
#
#
#  Progession: 11.11%
#
#
#  Progession: 14.81%
#
#
#  Progession: 18.52%
#
#
#  Progession: 22.22%
#
#
#  Progession: 25.93%
#
#
#  Progession: 29.63%
#
#
#  Progession: 33.33%
#
#
#  Progession: 37.04%
#
#
#  Progession: 40.74%
#
#
#  Progession: 44.44%
#
#
#  Progession: 48.15%
#
#
#  Progession: 51.85%
#
#
#  Progession: 55.56%
#
#
#  Progession: 59.26%
#
#
#  Progession: 62.96%
#
#
#  Progession: 66.67%
#
#
#  Progession: 70.37%
#
#
#  Progession: 74.07%
#
#
#  Progession: 77.78%
#
#
#  Progession: 81.48%
#
#
#  Progession: 85.19%
#
#
#  Progession: 88.89%
#
#
#  Progession: 92.59%
#
#
#  Progession: 96.3%
#
#
#  Progession: 100.0%
#
# ['Name', 'Path', 'Identity', 'Gender_code', 'Gender', 'Age', 'Race', 'date of birth', 'Emotion_code', 'Neutral', 'Anger', 'Scream', 'Contempt', 'Disgust', 'Fear', 'Happy', 'Sadness', 'Surprise', 'Sun glasses', 'Scarf', 'Eyeglasses', 'Beard', 'Hat', 'Angle']
# ...

# %%
with open("root_dir\datasets\labels\\fri_labels.csv","r",newline = '') as csv_file:
    csv_reader = csv.reader(csv_file)
    c=0
    for line in csv_reader:
        print(line)
# Out:
# ['Name', 'Path', 'Identity', 'Gender_code', 'Gender', 'Age', 'Race', 'date of birth', 'Emotion_code', 'Neutral', 'Anger', 'Scream', 'Contempt', 'Disgust', 'Fear', 'Happy', 'Sadness', 'Surprise', 'Sun glasses', 'Scarf', 'Eyeglasses', 'Beard', 'Hat', 'Angle']
# ['AjdaLampe.jpg', 'root_dir\\datasets\\original\\fri\\img\\AjdaLampe.jpg', 'AjdaLampe', '-1', 'Female', '', '', '', '0', '1', '', '', '', '', '', '', '', '', '', '', '-1', '-1', '-1', '']
# ['AlesJaklic.jpg', 'root_dir\\datasets\\original\\fri\\img\\AlesJaklic.jpg', 'AlesJaklic', '1', 'Male', '', '', '', '6', '', '', '', '', '', '', '1', '', '', '', '', '-1', '-1', '-1', '']
# ['AljosaBesednjak.png', 'root_dir\\datasets\\original\\fri\\img\\AljosaBesednjak.png', 'AljosaBesednjak', '1', 'Male', '', '', '', '6', '', '', '', '', '', '', '1', '', '', '', '', '-1', '-1', '-1', '']
# ...
